# %%
#project details
import simple_colors
print(simple_colors.magenta("\033[1m" + """                                task            :    cross validation 
                                learner name    :    J.Sudharsan
                                institute       :    GUVI""" + "\033[0m"))
# Out:
#                                 task            :    cross validation
#                                 learner name    :    J.Sudharsan
#                                 institute       :    GUVI

# %%
#)reading the dataset
print(simple_colors.red("reading the dataset"))
import pandas as pd
import math
df = pd.read_csv(r"D:\Sudharsan\Guvi_Data science\DS101_Sudharsan\Mainboot camp\data\loan_approval_dataset.csv")
df
# Out:
# reading the dataset
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
print(simple_colors.green("K-fold cross validation"))
#) importing necessary modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.model_selection import KFold, cross_val_score

cols = [' education',' self_employed',' loan_status']
df = pd.get_dummies(df,columns=cols,drop_first='True',dtype='int')

#) X and y
X =df.drop([' loan_status_ Rejected'],axis=1)
y = df[' loan_status_ Rejected']

#)splitting training and testing data
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

#) Ml models
models = [LogisticRegression(),
          KNeighborsClassifier(),
          SVC(),
          DecisionTreeClassifier(),
          RandomForestClassifier(),
          AdaBoostClassifier(),
          GradientBoostingClassifier()
         ]

k_folds = KFold(n_splits = 5)

for model in models:
    print(simple_colors.red(model))
    scores = cross_val_score(model, X, y, cv = k_folds)
    print(simple_colors.red(f"Cross Validation Scores:  {scores}"))
    print(simple_colors.green(f"Average CV Score: {scores.mean()}"))
    print(simple_colors.blue(f"Number of CV Scores used in Average: {len(scores)}"))
    print("\n\n")
# Out:
# K-fold cross validation
# LogisticRegression()
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
print(simple_colors.green("Stratified K-Fold"))
#) importing necessary modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.model_selection import StratifiedKFold, cross_val_score

#cols = [' education',' self_employed',' loan_status']
#df = pd.get_dummies(df,columns=cols,drop_first='True',dtype='int')

#) X and y
X =df.drop([' loan_status_ Rejected'],axis=1)
y = df[' loan_status_ Rejected']

#)splitting training and testing data
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

#) Ml models
models = [LogisticRegression(random_state=42),
          KNeighborsClassifier(),
          SVC(random_state=42),
          DecisionTreeClassifier(random_state=42),
          RandomForestClassifier(random_state=42),
          AdaBoostClassifier(random_state=42),
          GradientBoostingClassifier(random_state=42)
         ]

sk_folds = StratifiedKFold(n_splits = 5)

for model in models:
    print(simple_colors.red(model))
    scores = cross_val_score(model, X, y, cv = k_folds)
    print(simple_colors.red(f"Cross Validation Scores:  {scores}"))
    print(simple_colors.green(f"Average CV Score: {scores.mean()}"))
    print(simple_colors.blue(f"Number of CV Scores used in Average: {len(scores)}"))
    print("\n\n")
# Out:
# Stratified K-Fold
# LogisticRegression(random_state=42)
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
print(simple_colors.green("Leave-P-Out (LPO)"))
#) importing necessary modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.model_selection import LeavePOut, cross_val_score

#cols = [' education',' self_employed',' loan_status']
#df = pd.get_dummies(df,columns=cols,drop_first='True',dtype='int')

#) X and y
X =df.drop([' loan_status_ Rejected'],axis=1)
y = df[' loan_status_ Rejected']

#)splitting training and testing data
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

#) Ml models
models = [LogisticRegression(random_state=42),
          KNeighborsClassifier(),
          SVC(random_state=42),
          DecisionTreeClassifier(random_state=42),
          RandomForestClassifier(random_state=42),
          AdaBoostClassifier(random_state=42),
          GradientBoostingClassifier(random_state=42)
         ]

lpo = LeavePOut(p=2)

for model in models:
    print(simple_colors.red(model))
    scores = cross_val_score(model, X, y, cv = lpo)
    print(simple_colors.red(f"Cross Validation Scores:  {scores}"))
    print(simple_colors.green(f"Average CV Score: {scores.mean()}"))
    print(simple_colors.blue(f"Number of CV Scores used in Average: {len(scores)}"))
    print("\n\n")
# Out:
# Leave-P-Out (LPO)
# LogisticRegression(random_state=42)
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
print(simple_colors.green("shuffle split"))
#) importing necessary modules
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.model_selection import ShuffleSplit, cross_val_score

#cols = [' education',' self_employed',' loan_status']
#df = pd.get_dummies(df,columns=cols,drop_first='True',dtype='int')

#) X and y
X =df.drop([' loan_status_ Rejected'],axis=1)
y = df[' loan_status_ Rejected']

#)splitting training and testing data
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

#) Ml models
models = [LogisticRegression(random_state=42),
          KNeighborsClassifier(),
          SVC(random_state=42),
          DecisionTreeClassifier(random_state=42),
          RandomForestClassifier(random_state=42),
          AdaBoostClassifier(random_state=42),
          GradientBoostingClassifier(random_state=42)
         ]

ss = ShuffleSplit(train_size=0.6, test_size=0.3, n_splits = 5)

for model in models:
    print(simple_colors.red(model))
    scores = cross_val_score(model, X, y, cv = ss)
    print(simple_colors.red(f"Cross Validation Scores:  {scores}"))
    print(simple_colors.green(f"Average CV Score: {scores.mean()}"))
    print(simple_colors.blue(f"Number of CV Scores used in Average: {len(scores)}"))
    print("\n\n")
# Out:
# shuffle split
# LogisticRegression(random_state=42)
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\sjsud\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
